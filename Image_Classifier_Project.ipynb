# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 110842 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.1-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# Create a directory and mount Google Drive using that directory.
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
import os
os.listdir("drive")
# Out:
# ['.Trash',
#  '2014-Summer-REU-Personal-Information-Table-Aaron-Choi.doc',
#  '2014-Summer-REU-Personal-Information-Table-Aaron-Choi.doc.odt',
#  'Hackathon051515',
#  'me.obj',
#  'pegs.txt',
#  'In the android manifest file.docx',
#  'Copy of Bioregistry [elections].zip',
#  'Copy of Computer Systems Review.odt',
#  '20160830_134412.jpg',
#  'Book',
#  '20CS60335133Ass1(1).docx',
#  'rough.docx',
#  'proposal.docx',
#  'cheatsheetnetwork.docx',
#  'ResumeOmron.pdf',
#  'oshw.docx',
#  'ai.docx',
#  'hwos.docx',
#  'hwos.docx.odt',
#  'instructions.docx',
#  'finaldraftcsedu.docx.docx',
#  'Final Presentation part one.ppsx',
#  'part one (9f434ee4).pptx',
#  'part one.pptx',
#  '20170516_224334.mp4',
#  'Final Presentation part 2.pptx',
#  'japanese pop',
#  'Homework-1.docx',
#  'Homework-2.docx',
#  'new resume.docx',
#  'Untitled document.odt (e6676e38)',
#  'Untitled document.odt (935d310e)',
#  'Faster clocks.docx',
#  'Faster clocks.docx.odt',
#  'Decomposition of the Heart of the Cards.odt',
#  'Homework-9.docx',
#  'Homework-9.docx.odt',
#  'Homework-10(1).docx',
#  'Homework-10(1).docx.odt',
#  'Homework-11.docx',
#  'Untitled document.odt',
#  '20171207_155919.jpg',
#  '20171207_155902.jpg',
#  '20171207_155950.jpg',
#  '20171207_160003.jpg',
#  '20171207_155940 (ceac923d).jpg',
#  '20171207_155940.jpg',
#  '20171207_155927.jpg',
#  '20171207_160009.jpg',
#  '20171207_155937.jpg',
#  '20171207_155955.jpg',
#  'Senior Resume.docx',
#  'Senior Resume.docx.odt',
#  'Advanced Bracktology - Getting Started [for learners].pdf',
#  'Senior Resume.pdf',
#  'Cracking the Coding Interview 6th edition.pdf',
#  'results-20180308-223257.csv.ods',
#  'Homework 4.docx',
#  'Aaron_Choi_Sudoku.sml',
#  'Aaron_ChoiHW1.txt',
#  'Aaron_ChoiHW2.sml',
#  'ancestor.txt',
#  'first.sml',
#  'exam.txt',
#  'programming languages',
#  'self assessment.docx',
#  '[For Learners] NCAA Data Analysis on GCP.odt',
#  '12-the legendary theme (album version).mp3',
#  'Startup-Senior-Resume.pdf',
#  '00270_streaming.wav',
#  '00270_streaming.mp3',
#  '20180825_202850.jpg',
#  'Aaron Choi Offer Letter - Associate QA Engineer Offer Letter.PDF',
#  'Blank Release Form.pdf',
#  'Choi Onboarding Schedule.pub',
#  'Copy of Bioregistry.ods',
#  'Untitled form (Responses).ods',
#  'Colab Notebooks',
#  'Untitled0.ipynb',
#  'gogh.jpg',
#  'pytorchstory.jpg',
#  'persona5.jpg',
#  'flower_data',
#  'cat_to_name.json',
#  'checkpoint.pth',
#  'exp 1 5 epochs no dropout.odt',
#  'checkpoint1.pth',
#  'checkpoint2.pth',
#  'exp 1 20 epochs dropout and pre learning rate adjustment.odt',
#  'checkpoint3.pth',
#  'Untitled1.ipynb',
#  'mosaic-stained-glass-roots-catherine-van-der-woerd.jpg',
#  'stainedglassaaron.png',
#  'stained.jpeg',
#  'stainedglass2aaron.png',
#  'deku.jpg',
#  'me.jpg',
#  'iwai.png',
#  'yuyu.png',
#  'mangame.png',
#  'Choi Aaron 2013 Resume v1.docx.odt',
#  'Sequence 01_3.wmv',
#  'Bearcats MTG.txt',
#  'elections.zip',
#  'UC REU',
#  'Magic Club memembers information.zip',
#  '140816 Instructions to Complete 257 Interview Video.pdf']

# %%
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.0-{platform}-linux_x86_64.whl torchvision
# Out:
# tcmalloc: large alloc 1073750016 bytes == 0x5b4c6000 @  0x7f14a076a2a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641

# %%
# Imports here
import torch
import numpy as np
import matplotlib.pyplot as plt
import os, random
import json
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets, transforms, models
from collections import OrderedDict
from PIL import Image

# !pip uninstall -y Pillow
# !pip -q install Pillow==4.1.1
import time
# Out:
# Uninstalling Pillow-5.3.0:
#   Successfully uninstalled Pillow-5.3.0

# %%
# First checking if GPU is available
train_on_gpu=torch.cuda.is_available()

if(train_on_gpu):
    print('Training on GPU.')
else:
    print('No GPU available, training on CPU.')
# Out:
# Training on GPU.

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). You can [download the data here](https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip). The dataset is split into two parts, training and validation. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. If you use a pre-trained network, you'll also need to make sure the input data is resized to 224x224 pixels as required by the networks.
#
# The validation set is used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks available from `torchvision` were trained on the ImageNet dataset where each color channel was normalized separately. For both sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'drive/flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'

# %%
# TODO: Define your transforms for the training and validation sets
train_transforms = transforms.Compose([transforms.RandomResizedCrop(224),
                                      transforms.RandomRotation(30),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])
                                     ])

test_transforms = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.RandomRotation(30),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406], 
                                                          [0.229, 0.224, 0.225])
                                     ])

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
test_data  = datasets.ImageFolder(valid_dir, transform=test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
test_loader  = torch.utils.data.DataLoader(test_data, batch_size=32)

image_datasets = [train_data, test_data]
dataloaders = [train_loader, test_loader]

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('drive/cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students! You can also ask questions on the forums or join the instructors in office hours.
#
# Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.

# %%
# TODO: Build and train your network
# Load a pre-trained network
model = models.densenet121(pretrained=True)

# Freeze training for all "features" layers
for param in model.parameters():
    param.requires_grad = True
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.torch/models/densenet121-a639ec97.pth
# 100%|██████████| 32342954/32342954 [00:00<00:00, 56912285.80it/s]

# %%
model

# %%
# Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
classifier = nn.Sequential(nn.Linear(1024, 512),
                           nn.ReLU(),
                           nn.Dropout(0.5),
                           nn.Linear(512, 102),
                           nn.LogSoftmax(dim=1))

# %%
model.classifier = classifier

criterion = nn.NLLLoss()

optimizer = optim.Adadelta(model.classifier.parameters())

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


model.to(device);

# %%
epochs = 30
steps = 0
running_loss = 0
print_every = 5
for epoch in range(epochs):
  for inputs, labels in train_loader:
      steps += 1
      # Move input and label tensors to the default device
      inputs, labels = inputs.to(device), labels.to(device)

      optimizer.zero_grad()

      logps = model.forward(inputs)
      loss = criterion(logps, labels)
      loss.backward()
      optimizer.step()

      running_loss += loss.item()


      if steps % print_every == 0:
          test_loss = 0
          accuracy = 0
          model.eval()
          with torch.no_grad():
              for inputs, labels in test_loader:
                  inputs, labels = inputs.to(device), labels.to(device)
                  logps = model.forward(inputs)
                  batch_loss = criterion(logps, labels)

                  test_loss += batch_loss.item()

                  # Calculate accuracy
                  ps = torch.exp(logps)
                  top_p, top_class = ps.topk(1, dim=1)
                  equals = top_class == labels.view(*top_class.shape)
                  accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

          print(f"Epoch {epoch+1}/{epochs}.. "
                f"Train loss: {running_loss/print_every:.3f}.. "
                f"Test loss: {test_loss/len(test_loader):.3f}.. "
                f"Test accuracy: {accuracy/len(test_loader):.3f}")
          running_loss = 0
          model.train()
# Out:
# Epoch 1/30.. Train loss: 2.695.. Test loss: 2.310.. Test accuracy: 0.415
# Epoch 1/30.. Train loss: 2.730.. Test loss: 2.094.. Test accuracy: 0.489
# Epoch 1/30.. Train loss: 2.706.. Test loss: 1.959.. Test accuracy: 0.560
# Epoch 1/30.. Train loss: 2.482.. Test loss: 1.891.. Test accuracy: 0.587
# Epoch 1/30.. Train loss: 2.586.. Test loss: 1.892.. Test accuracy: 0.537
# Epoch 1/30.. Train loss: 2.573.. Test loss: 1.716.. Test accuracy: 0.639
# Epoch 1/30.. Train loss: 2.349.. Test loss: 1.760.. Test accuracy: 0.582
# Epoch 1/30.. Train loss: 2.576.. Test loss: 1.802.. Test accuracy: 0.558
# Epoch 1/30.. Train loss: 2.228.. Test loss: 1.712.. Test accuracy: 0.558
# Epoch 1/30.. Train loss: 2.546.. Test loss: 1.552.. Test accuracy: 0.637
# Epoch 1/30.. Train loss: 2.236.. Test loss: 1.440.. Test accuracy: 0.645
# Epoch 1/30.. Train loss: 2.319.. Test loss: 1.512.. Test accuracy: 0.597
# Epoch 1/30.. Train loss: 2.138.. Test loss: 1.361.. Test accuracy: 0.672
# Epoch 1/30.. Train loss: 2.286.. Test loss: 1.319.. Test accuracy: 0.679
# Epoch 1/30.. Train loss: 2.049.. Test loss: 1.257.. Test accuracy: 0.701
# Epoch 1/30.. Train loss: 2.026.. Test loss: 1.229.. Test accuracy: 0.701
# Epoch 1/30.. Train loss: 2.118.. Test loss: 1.285.. Test accuracy: 0.660
# Epoch 1/30.. Train loss: 1.950.. Test loss: 1.173.. Test accuracy: 0.703
# Epoch 1/30.. Train loss: 2.005.. Test loss: 1.242.. Test accuracy: 0.706
# Epoch 1/30.. Train loss: 1.978.. Test loss: 1.193.. Test accuracy: 0.702
# Epoch 2/30.. Train loss: 2.049.. Test loss: 1.190.. Test accuracy: 0.696
# Epoch 2/30.. Train loss: 1.791.. Test loss: 1.180.. Test accuracy: 0.695
# Epoch 2/30.. Train loss: 1.932.. Test loss: 1.074.. Test accuracy: 0.741
# Epoch 2/30.. Train loss: 1.892.. Test loss: 1.043.. Test accuracy: 0.757
# Epoch 2/30.. Train loss: 1.834.. Test loss: 1.064.. Test accuracy: 0.739
# Epoch 2/30.. Train loss: 1.752.. Test loss: 1.136.. Test accuracy: 0.685
# Epoch 2/30.. Train loss: 1.789.. Test loss: 0.926.. Test accuracy: 0.778
# Epoch 2/30.. Train loss: 1.826.. Test loss: 0.959.. Test accuracy: 0.756
# Epoch 2/30.. Train loss: 1.610.. Test loss: 0.974.. Test accuracy: 0.760
# Epoch 2/30.. Train loss: 1.687.. Test loss: 0.920.. Test accuracy: 0.782
# Epoch 2/30.. Train loss: 1.748.. Test loss: 0.953.. Test accuracy: 0.737
# Epoch 2/30.. Train loss: 1.664.. Test loss: 0.884.. Test accuracy: 0.779
# Epoch 2/30.. Train loss: 1.746.. Test loss: 0.978.. Test accuracy: 0.707
# Epoch 2/30.. Train loss: 1.717.. Test loss: 0.833.. Test accuracy: 0.794
# Epoch 2/30.. Train loss: 1.303.. Test loss: 0.927.. Test accuracy: 0.742
# Epoch 2/30.. Train loss: 1.681.. Test loss: 0.839.. Test accuracy: 0.770
# Epoch 2/30.. Train loss: 1.664.. Test loss: 0.857.. Test accuracy: 0.791
# Epoch 2/30.. Train loss: 1.593.. Test loss: 0.794.. Test accuracy: 0.813
# Epoch 2/30.. Train loss: 1.552.. Test loss: 0.830.. Test accuracy: 0.795
# Epoch 2/30.. Train loss: 1.471.. Test loss: 0.799.. Test accuracy: 0.798
# Epoch 2/30.. Train loss: 1.570.. Test loss: 0.748.. Test accuracy: 0.817
# Epoch 3/30.. Train loss: 1.322.. Test loss: 0.833.. Test accuracy: 0.779
# Epoch 3/30.. Train loss: 1.529.. Test loss: 0.812.. Test accuracy: 0.801
# Epoch 3/30.. Train loss: 1.681.. Test loss: 0.724.. Test accuracy: 0.832
# Epoch 3/30.. Train loss: 1.450.. Test loss: 0.755.. Test accuracy: 0.818
# Epoch 3/30.. Train loss: 1.561.. Test loss: 0.788.. Test accuracy: 0.788
# Epoch 3/30.. Train loss: 1.408.. Test loss: 0.725.. Test accuracy: 0.813
# Epoch 3/30.. Train loss: 1.516.. Test loss: 0.760.. Test accuracy: 0.782
# Epoch 3/30.. Train loss: 1.486.. Test loss: 0.774.. Test accuracy: 0.817
# Epoch 3/30.. Train loss: 1.513.. Test loss: 0.755.. Test accuracy: 0.802
# Epoch 3/30.. Train loss: 1.434.. Test loss: 0.682.. Test accuracy: 0.824
# Epoch 3/30.. Train loss: 1.508.. Test loss: 0.675.. Test accuracy: 0.828
# Epoch 3/30.. Train loss: 1.399.. Test loss: 0.700.. Test accuracy: 0.803
# Epoch 3/30.. Train loss: 1.327.. Test loss: 0.703.. Test accuracy: 0.819
# Epoch 3/30.. Train loss: 1.395.. Test loss: 0.724.. Test accuracy: 0.808
# Epoch 3/30.. Train loss: 1.338.. Test loss: 0.653.. Test accuracy: 0.829
# Epoch 3/30.. Train loss: 1.589.. Test loss: 0.692.. Test accuracy: 0.817
# Epoch 3/30.. Train loss: 1.527.. Test loss: 0.711.. Test accuracy: 0.800
# Epoch 3/30.. Train loss: 1.629.. Test loss: 0.666.. Test accuracy: 0.823
# Epoch 3/30.. Train loss: 1.336.. Test loss: 0.669.. Test accuracy: 0.805
# Epoch 3/30.. Train loss: 1.344.. Test loss: 0.654.. Test accuracy: 0.827
# Epoch 4/30.. Train loss: 1.418.. Test loss: 0.625.. Test accuracy: 0.832
# Epoch 4/30.. Train loss: 1.190.. Test loss: 0.618.. Test accuracy: 0.834
# Epoch 4/30.. Train loss: 1.359.. Test loss: 0.611.. Test accuracy: 0.826
# Epoch 4/30.. Train loss: 1.377.. Test loss: 0.654.. Test accuracy: 0.832
# Epoch 4/30.. Train loss: 1.301.. Test loss: 0.603.. Test accuracy: 0.846
# Epoch 4/30.. Train loss: 1.393.. Test loss: 0.651.. Test accuracy: 0.831
# Epoch 4/30.. Train loss: 1.248.. Test loss: 0.571.. Test accuracy: 0.855
# Epoch 4/30.. Train loss: 1.326.. Test loss: 0.636.. Test accuracy: 0.831
# Epoch 4/30.. Train loss: 1.403.. Test loss: 0.651.. Test accuracy: 0.813
# Epoch 4/30.. Train loss: 1.354.. Test loss: 0.666.. Test accuracy: 0.796
# Epoch 4/30.. Train loss: 1.333.. Test loss: 0.588.. Test accuracy: 0.839
# Epoch 4/30.. Train loss: 1.323.. Test loss: 0.599.. Test accuracy: 0.855
# Epoch 4/30.. Train loss: 1.294.. Test loss: 0.553.. Test accuracy: 0.850
# Epoch 4/30.. Train loss: 1.525.. Test loss: 0.646.. Test accuracy: 0.845
# Epoch 4/30.. Train loss: 1.384.. Test loss: 0.628.. Test accuracy: 0.826
# Epoch 4/30.. Train loss: 1.382.. Test loss: 0.573.. Test accuracy: 0.853
# Epoch 4/30.. Train loss: 1.334.. Test loss: 0.594.. Test accuracy: 0.836
# Epoch 4/30.. Train loss: 1.471.. Test loss: 0.594.. Test accuracy: 0.840
# Epoch 4/30.. Train loss: 1.274.. Test loss: 0.565.. Test accuracy: 0.861
# Epoch 4/30.. Train loss: 1.225.. Test loss: 0.516.. Test accuracy: 0.872
# Epoch 4/30.. Train loss: 1.234.. Test loss: 0.528.. Test accuracy: 0.855
# Epoch 5/30.. Train loss: 1.401.. Test loss: 0.576.. Test accuracy: 0.852
# Epoch 5/30.. Train loss: 1.174.. Test loss: 0.550.. Test accuracy: 0.842
# Epoch 5/30.. Train loss: 1.121.. Test loss: 0.619.. Test accuracy: 0.832
# Epoch 5/30.. Train loss: 1.216.. Test loss: 0.552.. Test accuracy: 0.860
# Epoch 5/30.. Train loss: 1.295.. Test loss: 0.509.. Test accuracy: 0.870
# Epoch 5/30.. Train loss: 0.992.. Test loss: 0.614.. Test accuracy: 0.842
# Epoch 5/30.. Train loss: 1.310.. Test loss: 0.600.. Test accuracy: 0.826
# Epoch 5/30.. Train loss: 1.298.. Test loss: 0.545.. Test accuracy: 0.845
# Epoch 5/30.. Train loss: 1.240.. Test loss: 0.561.. Test accuracy: 0.845
# Epoch 5/30.. Train loss: 1.325.. Test loss: 0.526.. Test accuracy: 0.871
# Epoch 5/30.. Train loss: 1.226.. Test loss: 0.535.. Test accuracy: 0.845
# Epoch 5/30.. Train loss: 1.277.. Test loss: 0.508.. Test accuracy: 0.860
# Epoch 5/30.. Train loss: 1.256.. Test loss: 0.512.. Test accuracy: 0.862
# Epoch 5/30.. Train loss: 1.330.. Test loss: 0.586.. Test accuracy: 0.831
# Epoch 5/30.. Train loss: 1.358.. Test loss: 0.581.. Test accuracy: 0.851
# Epoch 5/30.. Train loss: 1.272.. Test loss: 0.532.. Test accuracy: 0.850
# Epoch 5/30.. Train loss: 1.164.. Test loss: 0.489.. Test accuracy: 0.869
# Epoch 5/30.. Train loss: 1.091.. Test loss: 0.501.. Test accuracy: 0.865
# Epoch 5/30.. Train loss: 1.098.. Test loss: 0.520.. Test accuracy: 0.862
# Epoch 5/30.. Train loss: 1.204.. Test loss: 0.488.. Test accuracy: 0.879
# Epoch 5/30.. Train loss: 1.425.. Test loss: 0.555.. Test accuracy: 0.849
# Epoch 6/30.. Train loss: 1.286.. Test loss: 0.511.. Test accuracy: 0.858
# Epoch 6/30.. Train loss: 1.192.. Test loss: 0.504.. Test accuracy: 0.868
# Epoch 6/30.. Train loss: 1.351.. Test loss: 0.487.. Test accuracy: 0.876
# Epoch 6/30.. Train loss: 1.253.. Test loss: 0.479.. Test accuracy: 0.875
# Epoch 6/30.. Train loss: 1.325.. Test loss: 0.504.. Test accuracy: 0.871
# Epoch 6/30.. Train loss: 0.973.. Test loss: 0.493.. Test accuracy: 0.857
# Epoch 6/30.. Train loss: 1.215.. Test loss: 0.446.. Test accuracy: 0.882
# Epoch 6/30.. Train loss: 1.136.. Test loss: 0.478.. Test accuracy: 0.877
# Epoch 6/30.. Train loss: 1.186.. Test loss: 0.452.. Test accuracy: 0.880
# Epoch 6/30.. Train loss: 1.248.. Test loss: 0.463.. Test accuracy: 0.878
# Epoch 6/30.. Train loss: 1.100.. Test loss: 0.465.. Test accuracy: 0.878
# Epoch 6/30.. Train loss: 1.107.. Test loss: 0.463.. Test accuracy: 0.883
# Epoch 6/30.. Train loss: 1.062.. Test loss: 0.472.. Test accuracy: 0.865
# Epoch 6/30.. Train loss: 1.132.. Test loss: 0.468.. Test accuracy: 0.867
# Epoch 6/30.. Train loss: 1.041.. Test loss: 0.453.. Test accuracy: 0.883
# Epoch 6/30.. Train loss: 1.252.. Test loss: 0.442.. Test accuracy: 0.890
# Epoch 6/30.. Train loss: 1.032.. Test loss: 0.465.. Test accuracy: 0.874
# Epoch 6/30.. Train loss: 1.215.. Test loss: 0.445.. Test accuracy: 0.866
# Epoch 6/30.. Train loss: 1.095.. Test loss: 0.433.. Test accuracy: 0.885
# Epoch 6/30.. Train loss: 1.198.. Test loss: 0.440.. Test accuracy: 0.879
# Epoch 7/30.. Train loss: 1.251.. Test loss: 0.521.. Test accuracy: 0.856
# Epoch 7/30.. Train loss: 1.166.. Test loss: 0.455.. Test accuracy: 0.872
# Epoch 7/30.. Train loss: 1.230.. Test loss: 0.436.. Test accuracy: 0.886
# Epoch 7/30.. Train loss: 1.096.. Test loss: 0.456.. Test accuracy: 0.872
# Epoch 7/30.. Train loss: 1.142.. Test loss: 0.426.. Test accuracy: 0.893
# Epoch 7/30.. Train loss: 1.036.. Test loss: 0.457.. Test accuracy: 0.861
# Epoch 7/30.. Train loss: 1.036.. Test loss: 0.434.. Test accuracy: 0.872
# Epoch 7/30.. Train loss: 1.051.. Test loss: 0.461.. Test accuracy: 0.874
# Epoch 7/30.. Train loss: 1.080.. Test loss: 0.424.. Test accuracy: 0.880
# Epoch 7/30.. Train loss: 1.194.. Test loss: 0.449.. Test accuracy: 0.872
# Epoch 7/30.. Train loss: 1.001.. Test loss: 0.422.. Test accuracy: 0.888
# Epoch 7/30.. Train loss: 0.823.. Test loss: 0.375.. Test accuracy: 0.889
# Epoch 7/30.. Train loss: 1.097.. Test loss: 0.411.. Test accuracy: 0.891
# Epoch 7/30.. Train loss: 1.067.. Test loss: 0.428.. Test accuracy: 0.885
# Epoch 7/30.. Train loss: 1.025.. Test loss: 0.441.. Test accuracy: 0.888
# Epoch 7/30.. Train loss: 1.094.. Test loss: 0.472.. Test accuracy: 0.870
# Epoch 7/30.. Train loss: 1.058.. Test loss: 0.387.. Test accuracy: 0.899
# Epoch 7/30.. Train loss: 1.120.. Test loss: 0.395.. Test accuracy: 0.891
# Epoch 7/30.. Train loss: 1.087.. Test loss: 0.417.. Test accuracy: 0.881
# Epoch 7/30.. Train loss: 1.068.. Test loss: 0.417.. Test accuracy: 0.879
# Epoch 7/30.. Train loss: 0.923.. Test loss: 0.398.. Test accuracy: 0.886
# Epoch 8/30.. Train loss: 1.060.. Test loss: 0.404.. Test accuracy: 0.879
# Epoch 8/30.. Train loss: 1.118.. Test loss: 0.386.. Test accuracy: 0.902
# Epoch 8/30.. Train loss: 1.032.. Test loss: 0.435.. Test accuracy: 0.868
# Epoch 8/30.. Train loss: 1.155.. Test loss: 0.442.. Test accuracy: 0.880
# Epoch 8/30.. Train loss: 0.842.. Test loss: 0.381.. Test accuracy: 0.898
# Epoch 8/30.. Train loss: 1.051.. Test loss: 0.411.. Test accuracy: 0.889
# Epoch 8/30.. Train loss: 1.231.. Test loss: 0.424.. Test accuracy: 0.894
# Epoch 8/30.. Train loss: 1.166.. Test loss: 0.464.. Test accuracy: 0.869
# Epoch 8/30.. Train loss: 1.190.. Test loss: 0.442.. Test accuracy: 0.881
# Epoch 8/30.. Train loss: 1.083.. Test loss: 0.386.. Test accuracy: 0.891
# Epoch 8/30.. Train loss: 1.072.. Test loss: 0.410.. Test accuracy: 0.888
# Epoch 8/30.. Train loss: 1.056.. Test loss: 0.442.. Test accuracy: 0.890
# Epoch 8/30.. Train loss: 1.023.. Test loss: 0.399.. Test accuracy: 0.892
# Epoch 8/30.. Train loss: 1.093.. Test loss: 0.370.. Test accuracy: 0.888
# Epoch 8/30.. Train loss: 1.127.. Test loss: 0.428.. Test accuracy: 0.893
# Epoch 8/30.. Train loss: 1.053.. Test loss: 0.449.. Test accuracy: 0.860
# Epoch 8/30.. Train loss: 1.039.. Test loss: 0.382.. Test accuracy: 0.891
# Epoch 8/30.. Train loss: 1.073.. Test loss: 0.361.. Test accuracy: 0.906
# Epoch 8/30.. Train loss: 0.951.. Test loss: 0.446.. Test accuracy: 0.887
# Epoch 8/30.. Train loss: 1.137.. Test loss: 0.381.. Test accuracy: 0.892
# Epoch 9/30.. Train loss: 1.116.. Test loss: 0.398.. Test accuracy: 0.892
# Epoch 9/30.. Train loss: 1.012.. Test loss: 0.380.. Test accuracy: 0.899
# Epoch 9/30.. Train loss: 0.913.. Test loss: 0.416.. Test accuracy: 0.885
# Epoch 9/30.. Train loss: 1.066.. Test loss: 0.411.. Test accuracy: 0.882
# Epoch 9/30.. Train loss: 0.896.. Test loss: 0.414.. Test accuracy: 0.886
# Epoch 9/30.. Train loss: 0.928.. Test loss: 0.363.. Test accuracy: 0.914
# Epoch 9/30.. Train loss: 1.192.. Test loss: 0.418.. Test accuracy: 0.886
# Epoch 9/30.. Train loss: 1.028.. Test loss: 0.391.. Test accuracy: 0.900
# Epoch 9/30.. Train loss: 0.929.. Test loss: 0.377.. Test accuracy: 0.893
# Epoch 9/30.. Train loss: 0.933.. Test loss: 0.419.. Test accuracy: 0.871
# Epoch 9/30.. Train loss: 1.254.. Test loss: 0.369.. Test accuracy: 0.902
# Epoch 9/30.. Train loss: 1.041.. Test loss: 0.361.. Test accuracy: 0.884
# Epoch 9/30.. Train loss: 1.094.. Test loss: 0.386.. Test accuracy: 0.903
# Epoch 9/30.. Train loss: 0.983.. Test loss: 0.357.. Test accuracy: 0.902
# Epoch 9/30.. Train loss: 1.166.. Test loss: 0.357.. Test accuracy: 0.910
# Epoch 9/30.. Train loss: 0.937.. Test loss: 0.348.. Test accuracy: 0.899
# Epoch 9/30.. Train loss: 0.966.. Test loss: 0.398.. Test accuracy: 0.885
# Epoch 9/30.. Train loss: 0.983.. Test loss: 0.361.. Test accuracy: 0.897
# Epoch 9/30.. Train loss: 1.099.. Test loss: 0.360.. Test accuracy: 0.913
# Epoch 9/30.. Train loss: 0.979.. Test loss: 0.410.. Test accuracy: 0.876
# Epoch 9/30.. Train loss: 1.319.. Test loss: 0.434.. Test accuracy: 0.872
# Epoch 10/30.. Train loss: 1.450.. Test loss: 0.374.. Test accuracy: 0.899
# Epoch 10/30.. Train loss: 1.004.. Test loss: 0.390.. Test accuracy: 0.897
# Epoch 10/30.. Train loss: 1.032.. Test loss: 0.364.. Test accuracy: 0.907
# Epoch 10/30.. Train loss: 0.796.. Test loss: 0.370.. Test accuracy: 0.898
# Epoch 10/30.. Train loss: 0.911.. Test loss: 0.357.. Test accuracy: 0.903
# Epoch 10/30.. Train loss: 1.017.. Test loss: 0.328.. Test accuracy: 0.910
# Epoch 10/30.. Train loss: 1.090.. Test loss: 0.397.. Test accuracy: 0.897
# Epoch 10/30.. Train loss: 0.950.. Test loss: 0.385.. Test accuracy: 0.891
# Epoch 10/30.. Train loss: 0.933.. Test loss: 0.382.. Test accuracy: 0.885
# Epoch 10/30.. Train loss: 1.110.. Test loss: 0.382.. Test accuracy: 0.902
# Epoch 10/30.. Train loss: 0.981.. Test loss: 0.367.. Test accuracy: 0.908
# Epoch 10/30.. Train loss: 0.938.. Test loss: 0.363.. Test accuracy: 0.897
# Epoch 10/30.. Train loss: 1.023.. Test loss: 0.375.. Test accuracy: 0.887
# Epoch 10/30.. Train loss: 0.931.. Test loss: 0.391.. Test accuracy: 0.897
# Epoch 10/30.. Train loss: 0.958.. Test loss: 0.375.. Test accuracy: 0.894
# Epoch 10/30.. Train loss: 0.897.. Test loss: 0.403.. Test accuracy: 0.885
# Epoch 10/30.. Train loss: 0.854.. Test loss: 0.345.. Test accuracy: 0.893
# Epoch 10/30.. Train loss: 0.992.. Test loss: 0.405.. Test accuracy: 0.887
# Epoch 10/30.. Train loss: 1.209.. Test loss: 0.364.. Test accuracy: 0.902
# Epoch 10/30.. Train loss: 1.100.. Test loss: 0.362.. Test accuracy: 0.904
# Epoch 10/30.. Train loss: 1.152.. Test loss: 0.473.. Test accuracy: 0.870
# Epoch 11/30.. Train loss: 1.138.. Test loss: 0.443.. Test accuracy: 0.878
# Epoch 11/30.. Train loss: 1.099.. Test loss: 0.324.. Test accuracy: 0.913
# Epoch 11/30.. Train loss: 1.072.. Test loss: 0.376.. Test accuracy: 0.897
# Epoch 11/30.. Train loss: 0.915.. Test loss: 0.359.. Test accuracy: 0.891
# Epoch 11/30.. Train loss: 1.069.. Test loss: 0.356.. Test accuracy: 0.901
# Epoch 11/30.. Train loss: 0.970.. Test loss: 0.346.. Test accuracy: 0.916
# Epoch 11/30.. Train loss: 0.978.. Test loss: 0.353.. Test accuracy: 0.911
# Epoch 11/30.. Train loss: 1.019.. Test loss: 0.406.. Test accuracy: 0.889
# Epoch 11/30.. Train loss: 1.110.. Test loss: 0.377.. Test accuracy: 0.894
# Epoch 11/30.. Train loss: 1.088.. Test loss: 0.425.. Test accuracy: 0.890
# Epoch 11/30.. Train loss: 0.963.. Test loss: 0.351.. Test accuracy: 0.915
# Epoch 11/30.. Train loss: 0.934.. Test loss: 0.344.. Test accuracy: 0.907
# Epoch 11/30.. Train loss: 0.957.. Test loss: 0.428.. Test accuracy: 0.884
# Epoch 11/30.. Train loss: 1.042.. Test loss: 0.353.. Test accuracy: 0.904
# Epoch 11/30.. Train loss: 1.019.. Test loss: 0.433.. Test accuracy: 0.870
# Epoch 11/30.. Train loss: 0.967.. Test loss: 0.372.. Test accuracy: 0.885
# Epoch 11/30.. Train loss: 1.154.. Test loss: 0.367.. Test accuracy: 0.892
# Epoch 11/30.. Train loss: 0.918.. Test loss: 0.380.. Test accuracy: 0.899
# Epoch 11/30.. Train loss: 0.896.. Test loss: 0.332.. Test accuracy: 0.913
# Epoch 11/30.. Train loss: 1.022.. Test loss: 0.361.. Test accuracy: 0.894
# Epoch 12/30.. Train loss: 0.808.. Test loss: 0.357.. Test accuracy: 0.912
# Epoch 12/30.. Train loss: 1.011.. Test loss: 0.414.. Test accuracy: 0.885
# Epoch 12/30.. Train loss: 0.934.. Test loss: 0.381.. Test accuracy: 0.905
# Epoch 12/30.. Train loss: 1.092.. Test loss: 0.379.. Test accuracy: 0.902
# Epoch 12/30.. Train loss: 0.768.. Test loss: 0.382.. Test accuracy: 0.912
# Epoch 12/30.. Train loss: 0.865.. Test loss: 0.365.. Test accuracy: 0.901
# Epoch 12/30.. Train loss: 0.959.. Test loss: 0.393.. Test accuracy: 0.907
# Epoch 12/30.. Train loss: 1.080.. Test loss: 0.370.. Test accuracy: 0.900
# Epoch 12/30.. Train loss: 0.936.. Test loss: 0.358.. Test accuracy: 0.911
# Epoch 12/30.. Train loss: 1.009.. Test loss: 0.312.. Test accuracy: 0.917
# Epoch 12/30.. Train loss: 1.060.. Test loss: 0.359.. Test accuracy: 0.911
# Epoch 12/30.. Train loss: 0.969.. Test loss: 0.385.. Test accuracy: 0.888
# Epoch 12/30.. Train loss: 0.952.. Test loss: 0.319.. Test accuracy: 0.921
# Epoch 12/30.. Train loss: 1.130.. Test loss: 0.388.. Test accuracy: 0.899
# Epoch 12/30.. Train loss: 1.184.. Test loss: 0.355.. Test accuracy: 0.895
# Epoch 12/30.. Train loss: 1.057.. Test loss: 0.336.. Test accuracy: 0.909
# Epoch 12/30.. Train loss: 0.844.. Test loss: 0.347.. Test accuracy: 0.911
# Epoch 12/30.. Train loss: 0.946.. Test loss: 0.417.. Test accuracy: 0.887
# Epoch 12/30.. Train loss: 0.812.. Test loss: 0.337.. Test accuracy: 0.914
# Epoch 12/30.. Train loss: 0.943.. Test loss: 0.346.. Test accuracy: 0.908
# Epoch 12/30.. Train loss: 0.924.. Test loss: 0.344.. Test accuracy: 0.903
# Epoch 13/30.. Train loss: 0.991.. Test loss: 0.387.. Test accuracy: 0.897
# Epoch 13/30.. Train loss: 1.013.. Test loss: 0.390.. Test accuracy: 0.903
# Epoch 13/30.. Train loss: 1.035.. Test loss: 0.365.. Test accuracy: 0.903
# Epoch 13/30.. Train loss: 0.974.. Test loss: 0.365.. Test accuracy: 0.907
# Epoch 13/30.. Train loss: 0.985.. Test loss: 0.393.. Test accuracy: 0.885
# Epoch 13/30.. Train loss: 0.923.. Test loss: 0.381.. Test accuracy: 0.898
# Epoch 13/30.. Train loss: 0.866.. Test loss: 0.456.. Test accuracy: 0.885
# Epoch 13/30.. Train loss: 1.160.. Test loss: 0.343.. Test accuracy: 0.914
# Epoch 13/30.. Train loss: 0.960.. Test loss: 0.367.. Test accuracy: 0.910
# Epoch 13/30.. Train loss: 0.910.. Test loss: 0.359.. Test accuracy: 0.903
# Epoch 13/30.. Train loss: 0.996.. Test loss: 0.331.. Test accuracy: 0.913
# Epoch 13/30.. Train loss: 0.915.. Test loss: 0.364.. Test accuracy: 0.905
# Epoch 13/30.. Train loss: 0.854.. Test loss: 0.350.. Test accuracy: 0.907
# Epoch 13/30.. Train loss: 0.874.. Test loss: 0.349.. Test accuracy: 0.915
# Epoch 13/30.. Train loss: 0.955.. Test loss: 0.404.. Test accuracy: 0.894
# Epoch 13/30.. Train loss: 0.955.. Test loss: 0.366.. Test accuracy: 0.905
# Epoch 13/30.. Train loss: 1.093.. Test loss: 0.391.. Test accuracy: 0.890
# Epoch 13/30.. Train loss: 1.022.. Test loss: 0.320.. Test accuracy: 0.911
# Epoch 13/30.. Train loss: 0.982.. Test loss: 0.389.. Test accuracy: 0.897
# Epoch 13/30.. Train loss: 0.887.. Test loss: 0.396.. Test accuracy: 0.892
# Epoch 14/30.. Train loss: 0.911.. Test loss: 0.324.. Test accuracy: 0.902
# Epoch 14/30.. Train loss: 0.973.. Test loss: 0.342.. Test accuracy: 0.892
# Epoch 14/30.. Train loss: 0.943.. Test loss: 0.340.. Test accuracy: 0.908
# Epoch 14/30.. Train loss: 1.083.. Test loss: 0.355.. Test accuracy: 0.900
# Epoch 14/30.. Train loss: 0.693.. Test loss: 0.352.. Test accuracy: 0.901
# Epoch 14/30.. Train loss: 1.051.. Test loss: 0.352.. Test accuracy: 0.898
# Epoch 14/30.. Train loss: 1.103.. Test loss: 0.397.. Test accuracy: 0.885
# Epoch 14/30.. Train loss: 0.702.. Test loss: 0.347.. Test accuracy: 0.915
# Epoch 14/30.. Train loss: 1.002.. Test loss: 0.343.. Test accuracy: 0.909
# Epoch 14/30.. Train loss: 0.937.. Test loss: 0.343.. Test accuracy: 0.905
# Epoch 14/30.. Train loss: 0.851.. Test loss: 0.344.. Test accuracy: 0.915
# Epoch 14/30.. Train loss: 0.937.. Test loss: 0.373.. Test accuracy: 0.904
# Epoch 14/30.. Train loss: 0.839.. Test loss: 0.360.. Test accuracy: 0.901
# Epoch 14/30.. Train loss: 0.953.. Test loss: 0.369.. Test accuracy: 0.911
# Epoch 14/30.. Train loss: 0.927.. Test loss: 0.334.. Test accuracy: 0.908
# Epoch 14/30.. Train loss: 0.851.. Test loss: 0.366.. Test accuracy: 0.897
# Epoch 14/30.. Train loss: 1.010.. Test loss: 0.355.. Test accuracy: 0.903
# Epoch 14/30.. Train loss: 0.931.. Test loss: 0.362.. Test accuracy: 0.906
# Epoch 14/30.. Train loss: 0.774.. Test loss: 0.393.. Test accuracy: 0.902
# Epoch 14/30.. Train loss: 0.785.. Test loss: 0.406.. Test accuracy: 0.907
# Epoch 14/30.. Train loss: 0.849.. Test loss: 0.322.. Test accuracy: 0.917
# Epoch 15/30.. Train loss: 0.933.. Test loss: 0.378.. Test accuracy: 0.909
# Epoch 15/30.. Train loss: 0.790.. Test loss: 0.327.. Test accuracy: 0.915
# Epoch 15/30.. Train loss: 0.906.. Test loss: 0.340.. Test accuracy: 0.917
# Epoch 15/30.. Train loss: 0.959.. Test loss: 0.325.. Test accuracy: 0.907
# Epoch 15/30.. Train loss: 0.781.. Test loss: 0.373.. Test accuracy: 0.898
# Epoch 15/30.. Train loss: 1.058.. Test loss: 0.362.. Test accuracy: 0.907
# Epoch 15/30.. Train loss: 0.881.. Test loss: 0.370.. Test accuracy: 0.891
# Epoch 15/30.. Train loss: 0.734.. Test loss: 0.299.. Test accuracy: 0.916
# Epoch 15/30.. Train loss: 0.872.. Test loss: 0.352.. Test accuracy: 0.916
# Epoch 15/30.. Train loss: 1.301.. Test loss: 0.327.. Test accuracy: 0.896
# Epoch 15/30.. Train loss: 0.888.. Test loss: 0.306.. Test accuracy: 0.918
# Epoch 15/30.. Train loss: 0.921.. Test loss: 0.341.. Test accuracy: 0.911
# Epoch 15/30.. Train loss: 0.803.. Test loss: 0.335.. Test accuracy: 0.902
# Epoch 15/30.. Train loss: 0.928.. Test loss: 0.369.. Test accuracy: 0.916
# Epoch 15/30.. Train loss: 0.800.. Test loss: 0.319.. Test accuracy: 0.913
# Epoch 15/30.. Train loss: 0.763.. Test loss: 0.342.. Test accuracy: 0.899
# Epoch 15/30.. Train loss: 1.035.. Test loss: 0.381.. Test accuracy: 0.896
# Epoch 15/30.. Train loss: 1.015.. Test loss: 0.297.. Test accuracy: 0.922
# Epoch 15/30.. Train loss: 1.042.. Test loss: 0.316.. Test accuracy: 0.921
# Epoch 15/30.. Train loss: 0.887.. Test loss: 0.337.. Test accuracy: 0.902
# Epoch 15/30.. Train loss: 0.830.. Test loss: 0.372.. Test accuracy: 0.902
# Epoch 16/30.. Train loss: 0.920.. Test loss: 0.371.. Test accuracy: 0.909
# Epoch 16/30.. Train loss: 0.923.. Test loss: 0.360.. Test accuracy: 0.904
# Epoch 16/30.. Train loss: 1.030.. Test loss: 0.351.. Test accuracy: 0.915
# Epoch 16/30.. Train loss: 0.874.. Test loss: 0.330.. Test accuracy: 0.910
# Epoch 16/30.. Train loss: 0.951.. Test loss: 0.401.. Test accuracy: 0.899
# Epoch 16/30.. Train loss: 0.936.. Test loss: 0.327.. Test accuracy: 0.902
# Epoch 16/30.. Train loss: 1.066.. Test loss: 0.364.. Test accuracy: 0.905
# Epoch 16/30.. Train loss: 0.770.. Test loss: 0.369.. Test accuracy: 0.903
# Epoch 16/30.. Train loss: 0.862.. Test loss: 0.340.. Test accuracy: 0.903
# Epoch 16/30.. Train loss: 0.955.. Test loss: 0.327.. Test accuracy: 0.917
# Epoch 16/30.. Train loss: 0.941.. Test loss: 0.321.. Test accuracy: 0.925
# Epoch 16/30.. Train loss: 0.795.. Test loss: 0.336.. Test accuracy: 0.899
# Epoch 16/30.. Train loss: 0.912.. Test loss: 0.310.. Test accuracy: 0.909
# Epoch 16/30.. Train loss: 0.890.. Test loss: 0.325.. Test accuracy: 0.916
# Epoch 16/30.. Train loss: 0.924.. Test loss: 0.317.. Test accuracy: 0.923
# Epoch 16/30.. Train loss: 1.026.. Test loss: 0.318.. Test accuracy: 0.908
# Epoch 16/30.. Train loss: 0.781.. Test loss: 0.321.. Test accuracy: 0.915
# Epoch 16/30.. Train loss: 1.020.. Test loss: 0.342.. Test accuracy: 0.917
# Epoch 16/30.. Train loss: 0.777.. Test loss: 0.375.. Test accuracy: 0.896
# Epoch 16/30.. Train loss: 1.144.. Test loss: 0.323.. Test accuracy: 0.916
# Epoch 17/30.. Train loss: 1.082.. Test loss: 0.347.. Test accuracy: 0.910
# Epoch 17/30.. Train loss: 0.776.. Test loss: 0.313.. Test accuracy: 0.916
# Epoch 17/30.. Train loss: 0.991.. Test loss: 0.362.. Test accuracy: 0.899
# Epoch 17/30.. Train loss: 0.930.. Test loss: 0.289.. Test accuracy: 0.927
# Epoch 17/30.. Train loss: 0.882.. Test loss: 0.332.. Test accuracy: 0.916
# Epoch 17/30.. Train loss: 0.987.. Test loss: 0.333.. Test accuracy: 0.912
# Epoch 17/30.. Train loss: 0.894.. Test loss: 0.319.. Test accuracy: 0.913
# Epoch 17/30.. Train loss: 0.924.. Test loss: 0.323.. Test accuracy: 0.914
# Epoch 17/30.. Train loss: 0.948.. Test loss: 0.368.. Test accuracy: 0.909
# Epoch 17/30.. Train loss: 0.880.. Test loss: 0.325.. Test accuracy: 0.911
# Epoch 17/30.. Train loss: 0.801.. Test loss: 0.302.. Test accuracy: 0.919
# Epoch 17/30.. Train loss: 0.832.. Test loss: 0.326.. Test accuracy: 0.915
# Epoch 17/30.. Train loss: 0.926.. Test loss: 0.277.. Test accuracy: 0.926
# Epoch 17/30.. Train loss: 0.961.. Test loss: 0.354.. Test accuracy: 0.922
# Epoch 17/30.. Train loss: 0.906.. Test loss: 0.336.. Test accuracy: 0.911
# Epoch 17/30.. Train loss: 0.769.. Test loss: 0.338.. Test accuracy: 0.921
# Epoch 17/30.. Train loss: 0.928.. Test loss: 0.343.. Test accuracy: 0.904
# Epoch 17/30.. Train loss: 0.974.. Test loss: 0.355.. Test accuracy: 0.891
# Epoch 17/30.. Train loss: 1.052.. Test loss: 0.353.. Test accuracy: 0.910
# Epoch 17/30.. Train loss: 0.852.. Test loss: 0.318.. Test accuracy: 0.917
# Epoch 17/30.. Train loss: 0.960.. Test loss: 0.312.. Test accuracy: 0.921
# Epoch 18/30.. Train loss: 0.861.. Test loss: 0.342.. Test accuracy: 0.902
# Epoch 18/30.. Train loss: 0.911.. Test loss: 0.313.. Test accuracy: 0.913
# Epoch 18/30.. Train loss: 0.741.. Test loss: 0.319.. Test accuracy: 0.907
# Epoch 18/30.. Train loss: 0.910.. Test loss: 0.300.. Test accuracy: 0.923
# Epoch 18/30.. Train loss: 0.652.. Test loss: 0.323.. Test accuracy: 0.905
# Epoch 18/30.. Train loss: 0.850.. Test loss: 0.321.. Test accuracy: 0.907
# Epoch 18/30.. Train loss: 0.860.. Test loss: 0.359.. Test accuracy: 0.911
# Epoch 18/30.. Train loss: 0.903.. Test loss: 0.335.. Test accuracy: 0.912
# Epoch 18/30.. Train loss: 0.901.. Test loss: 0.314.. Test accuracy: 0.913
# Epoch 18/30.. Train loss: 0.962.. Test loss: 0.358.. Test accuracy: 0.909
# Epoch 18/30.. Train loss: 0.949.. Test loss: 0.351.. Test accuracy: 0.910
# Epoch 18/30.. Train loss: 0.870.. Test loss: 0.315.. Test accuracy: 0.911
# Epoch 18/30.. Train loss: 0.988.. Test loss: 0.336.. Test accuracy: 0.913
# Epoch 18/30.. Train loss: 0.803.. Test loss: 0.341.. Test accuracy: 0.916
# Epoch 18/30.. Train loss: 0.961.. Test loss: 0.352.. Test accuracy: 0.908
# Epoch 18/30.. Train loss: 0.744.. Test loss: 0.287.. Test accuracy: 0.926
# Epoch 18/30.. Train loss: 1.032.. Test loss: 0.280.. Test accuracy: 0.929
# Epoch 18/30.. Train loss: 0.729.. Test loss: 0.310.. Test accuracy: 0.917
# Epoch 18/30.. Train loss: 1.112.. Test loss: 0.302.. Test accuracy: 0.915
# Epoch 18/30.. Train loss: 0.737.. Test loss: 0.303.. Test accuracy: 0.929
# Epoch 19/30.. Train loss: 1.096.. Test loss: 0.343.. Test accuracy: 0.908
# Epoch 19/30.. Train loss: 0.984.. Test loss: 0.347.. Test accuracy: 0.906
# Epoch 19/30.. Train loss: 0.895.. Test loss: 0.314.. Test accuracy: 0.906
# Epoch 19/30.. Train loss: 0.842.. Test loss: 0.300.. Test accuracy: 0.914
# Epoch 19/30.. Train loss: 0.899.. Test loss: 0.321.. Test accuracy: 0.916
# Epoch 19/30.. Train loss: 1.058.. Test loss: 0.298.. Test accuracy: 0.916
# Epoch 19/30.. Train loss: 0.799.. Test loss: 0.325.. Test accuracy: 0.917
# Epoch 19/30.. Train loss: 0.763.. Test loss: 0.309.. Test accuracy: 0.918
# Epoch 19/30.. Train loss: 0.935.. Test loss: 0.342.. Test accuracy: 0.912
# Epoch 19/30.. Train loss: 0.862.. Test loss: 0.278.. Test accuracy: 0.928
# Epoch 19/30.. Train loss: 0.923.. Test loss: 0.307.. Test accuracy: 0.923
# Epoch 19/30.. Train loss: 1.023.. Test loss: 0.337.. Test accuracy: 0.903
# Epoch 19/30.. Train loss: 0.870.. Test loss: 0.292.. Test accuracy: 0.918
# Epoch 19/30.. Train loss: 0.919.. Test loss: 0.307.. Test accuracy: 0.920
# Epoch 19/30.. Train loss: 0.932.. Test loss: 0.317.. Test accuracy: 0.916
# Epoch 19/30.. Train loss: 0.865.. Test loss: 0.347.. Test accuracy: 0.907
# Epoch 19/30.. Train loss: 0.766.. Test loss: 0.311.. Test accuracy: 0.921
# Epoch 19/30.. Train loss: 0.792.. Test loss: 0.285.. Test accuracy: 0.929
# Epoch 19/30.. Train loss: 0.878.. Test loss: 0.316.. Test accuracy: 0.922
# Epoch 19/30.. Train loss: 0.884.. Test loss: 0.355.. Test accuracy: 0.904
# Epoch 19/30.. Train loss: 1.016.. Test loss: 0.296.. Test accuracy: 0.916
# Epoch 20/30.. Train loss: 0.858.. Test loss: 0.348.. Test accuracy: 0.895
# Epoch 20/30.. Train loss: 0.746.. Test loss: 0.321.. Test accuracy: 0.910
# Epoch 20/30.. Train loss: 0.748.. Test loss: 0.331.. Test accuracy: 0.905
# Epoch 20/30.. Train loss: 1.112.. Test loss: 0.315.. Test accuracy: 0.916
# Epoch 20/30.. Train loss: 0.841.. Test loss: 0.338.. Test accuracy: 0.915
# Epoch 20/30.. Train loss: 0.876.. Test loss: 0.345.. Test accuracy: 0.908
# Epoch 20/30.. Train loss: 0.845.. Test loss: 0.299.. Test accuracy: 0.928
# Epoch 20/30.. Train loss: 0.775.. Test loss: 0.313.. Test accuracy: 0.921
# Epoch 20/30.. Train loss: 0.831.. Test loss: 0.273.. Test accuracy: 0.916
# Epoch 20/30.. Train loss: 0.948.. Test loss: 0.297.. Test accuracy: 0.916
# Epoch 20/30.. Train loss: 0.883.. Test loss: 0.301.. Test accuracy: 0.919
# Epoch 20/30.. Train loss: 0.979.. Test loss: 0.344.. Test accuracy: 0.903
# Epoch 20/30.. Train loss: 0.920.. Test loss: 0.306.. Test accuracy: 0.922
# Epoch 20/30.. Train loss: 0.871.. Test loss: 0.296.. Test accuracy: 0.919
# Epoch 20/30.. Train loss: 0.905.. Test loss: 0.351.. Test accuracy: 0.909
# Epoch 20/30.. Train loss: 0.852.. Test loss: 0.321.. Test accuracy: 0.919
# Epoch 20/30.. Train loss: 0.944.. Test loss: 0.376.. Test accuracy: 0.892
# Epoch 20/30.. Train loss: 0.969.. Test loss: 0.315.. Test accuracy: 0.916
# Epoch 20/30.. Train loss: 0.693.. Test loss: 0.308.. Test accuracy: 0.915
# Epoch 20/30.. Train loss: 0.934.. Test loss: 0.311.. Test accuracy: 0.915
# Epoch 20/30.. Train loss: 1.012.. Test loss: 0.367.. Test accuracy: 0.900
# Epoch 21/30.. Train loss: 0.751.. Test loss: 0.361.. Test accuracy: 0.905
# Epoch 21/30.. Train loss: 1.045.. Test loss: 0.335.. Test accuracy: 0.915
# Epoch 21/30.. Train loss: 0.923.. Test loss: 0.328.. Test accuracy: 0.914
# Epoch 21/30.. Train loss: 0.772.. Test loss: 0.356.. Test accuracy: 0.899
# Epoch 21/30.. Train loss: 0.701.. Test loss: 0.339.. Test accuracy: 0.915
# Epoch 21/30.. Train loss: 1.004.. Test loss: 0.359.. Test accuracy: 0.899
# Epoch 21/30.. Train loss: 0.825.. Test loss: 0.285.. Test accuracy: 0.920
# Epoch 21/30.. Train loss: 0.933.. Test loss: 0.348.. Test accuracy: 0.908
# Epoch 21/30.. Train loss: 0.888.. Test loss: 0.315.. Test accuracy: 0.917
# Epoch 21/30.. Train loss: 0.852.. Test loss: 0.300.. Test accuracy: 0.914
# Epoch 21/30.. Train loss: 0.792.. Test loss: 0.311.. Test accuracy: 0.912
# Epoch 21/30.. Train loss: 0.761.. Test loss: 0.308.. Test accuracy: 0.914
# Epoch 21/30.. Train loss: 0.846.. Test loss: 0.311.. Test accuracy: 0.915
# Epoch 21/30.. Train loss: 0.823.. Test loss: 0.317.. Test accuracy: 0.921
# Epoch 21/30.. Train loss: 0.966.. Test loss: 0.306.. Test accuracy: 0.927
# Epoch 21/30.. Train loss: 0.829.. Test loss: 0.347.. Test accuracy: 0.912
# Epoch 21/30.. Train loss: 1.093.. Test loss: 0.332.. Test accuracy: 0.915
# Epoch 21/30.. Train loss: 0.959.. Test loss: 0.294.. Test accuracy: 0.914
# Epoch 21/30.. Train loss: 0.855.. Test loss: 0.318.. Test accuracy: 0.912
# Epoch 21/30.. Train loss: 0.921.. Test loss: 0.301.. Test accuracy: 0.915
# Epoch 22/30.. Train loss: 0.894.. Test loss: 0.356.. Test accuracy: 0.910
# Epoch 22/30.. Train loss: 1.053.. Test loss: 0.342.. Test accuracy: 0.897
# Epoch 22/30.. Train loss: 1.020.. Test loss: 0.295.. Test accuracy: 0.910
# Epoch 22/30.. Train loss: 0.772.. Test loss: 0.316.. Test accuracy: 0.919
# Epoch 22/30.. Train loss: 0.840.. Test loss: 0.313.. Test accuracy: 0.913
# Epoch 22/30.. Train loss: 0.833.. Test loss: 0.356.. Test accuracy: 0.889
# Epoch 22/30.. Train loss: 0.944.. Test loss: 0.288.. Test accuracy: 0.918
# Epoch 22/30.. Train loss: 0.699.. Test loss: 0.349.. Test accuracy: 0.903
# Epoch 22/30.. Train loss: 0.747.. Test loss: 0.310.. Test accuracy: 0.922
# Epoch 22/30.. Train loss: 0.914.. Test loss: 0.338.. Test accuracy: 0.910
# Epoch 22/30.. Train loss: 0.861.. Test loss: 0.368.. Test accuracy: 0.903
# Epoch 22/30.. Train loss: 0.916.. Test loss: 0.313.. Test accuracy: 0.914
# Epoch 22/30.. Train loss: 1.043.. Test loss: 0.393.. Test accuracy: 0.908
# Epoch 22/30.. Train loss: 0.898.. Test loss: 0.309.. Test accuracy: 0.919
# Epoch 22/30.. Train loss: 0.890.. Test loss: 0.337.. Test accuracy: 0.913
# Epoch 22/30.. Train loss: 0.901.. Test loss: 0.309.. Test accuracy: 0.917
# Epoch 22/30.. Train loss: 0.808.. Test loss: 0.327.. Test accuracy: 0.910
# Epoch 22/30.. Train loss: 0.688.. Test loss: 0.338.. Test accuracy: 0.906
# Epoch 22/30.. Train loss: 0.796.. Test loss: 0.314.. Test accuracy: 0.919
# Epoch 22/30.. Train loss: 0.714.. Test loss: 0.324.. Test accuracy: 0.916
# Epoch 22/30.. Train loss: 0.833.. Test loss: 0.316.. Test accuracy: 0.912
# Epoch 23/30.. Train loss: 0.753.. Test loss: 0.321.. Test accuracy: 0.910
# Epoch 23/30.. Train loss: 0.739.. Test loss: 0.289.. Test accuracy: 0.920
# Epoch 23/30.. Train loss: 0.961.. Test loss: 0.291.. Test accuracy: 0.922
# Epoch 23/30.. Train loss: 1.003.. Test loss: 0.333.. Test accuracy: 0.907
# Epoch 23/30.. Train loss: 0.875.. Test loss: 0.310.. Test accuracy: 0.910
# Epoch 23/30.. Train loss: 0.808.. Test loss: 0.326.. Test accuracy: 0.921
# Epoch 23/30.. Train loss: 0.795.. Test loss: 0.270.. Test accuracy: 0.922
# Epoch 23/30.. Train loss: 0.752.. Test loss: 0.323.. Test accuracy: 0.909
# Epoch 23/30.. Train loss: 0.960.. Test loss: 0.294.. Test accuracy: 0.925
# Epoch 23/30.. Train loss: 0.925.. Test loss: 0.318.. Test accuracy: 0.919
# Epoch 23/30.. Train loss: 0.931.. Test loss: 0.328.. Test accuracy: 0.914
# Epoch 23/30.. Train loss: 0.834.. Test loss: 0.332.. Test accuracy: 0.908
# Epoch 23/30.. Train loss: 0.839.. Test loss: 0.314.. Test accuracy: 0.907
# Epoch 23/30.. Train loss: 0.852.. Test loss: 0.288.. Test accuracy: 0.920
# Epoch 23/30.. Train loss: 0.762.. Test loss: 0.303.. Test accuracy: 0.923
# Epoch 23/30.. Train loss: 0.810.. Test loss: 0.292.. Test accuracy: 0.925
# Epoch 23/30.. Train loss: 0.781.. Test loss: 0.341.. Test accuracy: 0.902
# Epoch 23/30.. Train loss: 0.828.. Test loss: 0.318.. Test accuracy: 0.913
# Epoch 23/30.. Train loss: 0.954.. Test loss: 0.321.. Test accuracy: 0.912
# Epoch 23/30.. Train loss: 0.836.. Test loss: 0.321.. Test accuracy: 0.911
# Epoch 24/30.. Train loss: 0.998.. Test loss: 0.328.. Test accuracy: 0.925
# Epoch 24/30.. Train loss: 0.824.. Test loss: 0.334.. Test accuracy: 0.910
# Epoch 24/30.. Train loss: 0.880.. Test loss: 0.345.. Test accuracy: 0.920
# Epoch 24/30.. Train loss: 0.950.. Test loss: 0.303.. Test accuracy: 0.925
# Epoch 24/30.. Train loss: 0.878.. Test loss: 0.298.. Test accuracy: 0.921
# Epoch 24/30.. Train loss: 0.699.. Test loss: 0.327.. Test accuracy: 0.913
# Epoch 24/30.. Train loss: 0.822.. Test loss: 0.314.. Test accuracy: 0.916
# Epoch 24/30.. Train loss: 0.872.. Test loss: 0.366.. Test accuracy: 0.910
# Epoch 24/30.. Train loss: 0.927.. Test loss: 0.300.. Test accuracy: 0.920
# Epoch 24/30.. Train loss: 0.725.. Test loss: 0.336.. Test accuracy: 0.916
# Epoch 24/30.. Train loss: 0.765.. Test loss: 0.287.. Test accuracy: 0.925
# Epoch 24/30.. Train loss: 0.881.. Test loss: 0.303.. Test accuracy: 0.921
# Epoch 24/30.. Train loss: 0.887.. Test loss: 0.323.. Test accuracy: 0.920
# Epoch 24/30.. Train loss: 0.736.. Test loss: 0.342.. Test accuracy: 0.913
# Epoch 24/30.. Train loss: 0.565.. Test loss: 0.314.. Test accuracy: 0.919
# Epoch 24/30.. Train loss: 0.990.. Test loss: 0.369.. Test accuracy: 0.900
# Epoch 24/30.. Train loss: 0.817.. Test loss: 0.301.. Test accuracy: 0.926
# Epoch 24/30.. Train loss: 0.789.. Test loss: 0.295.. Test accuracy: 0.928
# Epoch 24/30.. Train loss: 0.908.. Test loss: 0.301.. Test accuracy: 0.916
# Epoch 24/30.. Train loss: 0.694.. Test loss: 0.346.. Test accuracy: 0.902
# Epoch 24/30.. Train loss: 0.803.. Test loss: 0.321.. Test accuracy: 0.923
# Epoch 25/30.. Train loss: 0.829.. Test loss: 0.313.. Test accuracy: 0.920
# Epoch 25/30.. Train loss: 0.749.. Test loss: 0.308.. Test accuracy: 0.923
# Epoch 25/30.. Train loss: 0.782.. Test loss: 0.330.. Test accuracy: 0.925
# Epoch 25/30.. Train loss: 0.803.. Test loss: 0.300.. Test accuracy: 0.916
# Epoch 25/30.. Train loss: 0.889.. Test loss: 0.307.. Test accuracy: 0.929
# Epoch 25/30.. Train loss: 0.775.. Test loss: 0.271.. Test accuracy: 0.931
# Epoch 25/30.. Train loss: 0.753.. Test loss: 0.316.. Test accuracy: 0.909
# Epoch 25/30.. Train loss: 0.806.. Test loss: 0.299.. Test accuracy: 0.926
# Epoch 25/30.. Train loss: 0.833.. Test loss: 0.311.. Test accuracy: 0.918
# Epoch 25/30.. Train loss: 0.748.. Test loss: 0.334.. Test accuracy: 0.907
# Epoch 25/30.. Train loss: 0.861.. Test loss: 0.325.. Test accuracy: 0.908
# Epoch 25/30.. Train loss: 0.833.. Test loss: 0.286.. Test accuracy: 0.920
# Epoch 25/30.. Train loss: 0.866.. Test loss: 0.296.. Test accuracy: 0.923
# Epoch 25/30.. Train loss: 0.785.. Test loss: 0.320.. Test accuracy: 0.916
# Epoch 25/30.. Train loss: 0.775.. Test loss: 0.294.. Test accuracy: 0.915
# Epoch 25/30.. Train loss: 0.908.. Test loss: 0.314.. Test accuracy: 0.916
# Epoch 25/30.. Train loss: 0.926.. Test loss: 0.385.. Test accuracy: 0.902
# Epoch 25/30.. Train loss: 0.907.. Test loss: 0.294.. Test accuracy: 0.915
# Epoch 25/30.. Train loss: 0.863.. Test loss: 0.271.. Test accuracy: 0.923
# Epoch 25/30.. Train loss: 0.885.. Test loss: 0.337.. Test accuracy: 0.906
# Epoch 25/30.. Train loss: 1.048.. Test loss: 0.328.. Test accuracy: 0.896
# Epoch 26/30.. Train loss: 0.827.. Test loss: 0.324.. Test accuracy: 0.909
# Epoch 26/30.. Train loss: 0.759.. Test loss: 0.297.. Test accuracy: 0.921
# Epoch 26/30.. Train loss: 0.819.. Test loss: 0.351.. Test accuracy: 0.915
# Epoch 26/30.. Train loss: 0.662.. Test loss: 0.306.. Test accuracy: 0.920
# Epoch 26/30.. Train loss: 1.062.. Test loss: 0.323.. Test accuracy: 0.909
# Epoch 26/30.. Train loss: 0.942.. Test loss: 0.331.. Test accuracy: 0.912
# Epoch 26/30.. Train loss: 1.100.. Test loss: 0.287.. Test accuracy: 0.923
# Epoch 26/30.. Train loss: 0.822.. Test loss: 0.336.. Test accuracy: 0.912
# Epoch 26/30.. Train loss: 0.880.. Test loss: 0.324.. Test accuracy: 0.923
# Epoch 26/30.. Train loss: 0.859.. Test loss: 0.310.. Test accuracy: 0.915
# Epoch 26/30.. Train loss: 0.773.. Test loss: 0.378.. Test accuracy: 0.904
# Epoch 26/30.. Train loss: 0.828.. Test loss: 0.322.. Test accuracy: 0.917
# Epoch 26/30.. Train loss: 0.921.. Test loss: 0.349.. Test accuracy: 0.921
# Epoch 26/30.. Train loss: 0.790.. Test loss: 0.302.. Test accuracy: 0.923
# Epoch 26/30.. Train loss: 0.733.. Test loss: 0.317.. Test accuracy: 0.916
# Epoch 26/30.. Train loss: 1.053.. Test loss: 0.306.. Test accuracy: 0.922
# Epoch 26/30.. Train loss: 0.780.. Test loss: 0.292.. Test accuracy: 0.928
# Epoch 26/30.. Train loss: 0.790.. Test loss: 0.306.. Test accuracy: 0.912
# Epoch 26/30.. Train loss: 0.803.. Test loss: 0.297.. Test accuracy: 0.925
# Epoch 26/30.. Train loss: 0.822.. Test loss: 0.298.. Test accuracy: 0.927
# Epoch 27/30.. Train loss: 0.892.. Test loss: 0.309.. Test accuracy: 0.923
# Epoch 27/30.. Train loss: 0.886.. Test loss: 0.334.. Test accuracy: 0.915
# Epoch 27/30.. Train loss: 0.903.. Test loss: 0.309.. Test accuracy: 0.926
# Epoch 27/30.. Train loss: 0.890.. Test loss: 0.313.. Test accuracy: 0.926
# Epoch 27/30.. Train loss: 0.841.. Test loss: 0.312.. Test accuracy: 0.928
# Epoch 27/30.. Train loss: 0.800.. Test loss: 0.297.. Test accuracy: 0.919
# Epoch 27/30.. Train loss: 0.777.. Test loss: 0.339.. Test accuracy: 0.895
# Epoch 27/30.. Train loss: 0.959.. Test loss: 0.333.. Test accuracy: 0.915
# Epoch 27/30.. Train loss: 0.877.. Test loss: 0.354.. Test accuracy: 0.915
# Epoch 27/30.. Train loss: 0.778.. Test loss: 0.341.. Test accuracy: 0.913
# Epoch 27/30.. Train loss: 0.935.. Test loss: 0.290.. Test accuracy: 0.921
# Epoch 27/30.. Train loss: 0.807.. Test loss: 0.311.. Test accuracy: 0.924
# Epoch 27/30.. Train loss: 0.856.. Test loss: 0.295.. Test accuracy: 0.924
# Epoch 27/30.. Train loss: 0.814.. Test loss: 0.329.. Test accuracy: 0.922
# Epoch 27/30.. Train loss: 0.912.. Test loss: 0.340.. Test accuracy: 0.909
# Epoch 27/30.. Train loss: 0.838.. Test loss: 0.305.. Test accuracy: 0.915
# Epoch 27/30.. Train loss: 0.843.. Test loss: 0.338.. Test accuracy: 0.910
# Epoch 27/30.. Train loss: 0.852.. Test loss: 0.295.. Test accuracy: 0.924
# Epoch 27/30.. Train loss: 0.571.. Test loss: 0.300.. Test accuracy: 0.924
# Epoch 27/30.. Train loss: 0.893.. Test loss: 0.322.. Test accuracy: 0.922
# Epoch 27/30.. Train loss: 0.886.. Test loss: 0.305.. Test accuracy: 0.916
# Epoch 28/30.. Train loss: 0.756.. Test loss: 0.297.. Test accuracy: 0.923
# Epoch 28/30.. Train loss: 0.673.. Test loss: 0.275.. Test accuracy: 0.931
# Epoch 28/30.. Train loss: 0.746.. Test loss: 0.288.. Test accuracy: 0.916
# Epoch 28/30.. Train loss: 0.698.. Test loss: 0.303.. Test accuracy: 0.922
# Epoch 28/30.. Train loss: 0.804.. Test loss: 0.328.. Test accuracy: 0.908
# Epoch 28/30.. Train loss: 0.822.. Test loss: 0.293.. Test accuracy: 0.937
# Epoch 28/30.. Train loss: 0.906.. Test loss: 0.286.. Test accuracy: 0.927
# Epoch 28/30.. Train loss: 0.977.. Test loss: 0.287.. Test accuracy: 0.924
# Epoch 28/30.. Train loss: 0.874.. Test loss: 0.306.. Test accuracy: 0.923
# Epoch 28/30.. Train loss: 0.960.. Test loss: 0.288.. Test accuracy: 0.924
# Epoch 28/30.. Train loss: 0.830.. Test loss: 0.292.. Test accuracy: 0.931
# Epoch 28/30.. Train loss: 0.799.. Test loss: 0.324.. Test accuracy: 0.914
# Epoch 28/30.. Train loss: 0.786.. Test loss: 0.329.. Test accuracy: 0.919
# Epoch 28/30.. Train loss: 0.944.. Test loss: 0.316.. Test accuracy: 0.926
# Epoch 28/30.. Train loss: 0.801.. Test loss: 0.278.. Test accuracy: 0.924
# Epoch 28/30.. Train loss: 0.795.. Test loss: 0.315.. Test accuracy: 0.921
# Epoch 28/30.. Train loss: 0.889.. Test loss: 0.336.. Test accuracy: 0.907
# Epoch 28/30.. Train loss: 0.923.. Test loss: 0.300.. Test accuracy: 0.927
# Epoch 28/30.. Train loss: 0.984.. Test loss: 0.282.. Test accuracy: 0.920
# Epoch 28/30.. Train loss: 0.799.. Test loss: 0.287.. Test accuracy: 0.927
# Epoch 29/30.. Train loss: 0.866.. Test loss: 0.298.. Test accuracy: 0.903
# Epoch 29/30.. Train loss: 0.796.. Test loss: 0.326.. Test accuracy: 0.915
# Epoch 29/30.. Train loss: 0.830.. Test loss: 0.318.. Test accuracy: 0.914
# Epoch 29/30.. Train loss: 0.736.. Test loss: 0.329.. Test accuracy: 0.926
# Epoch 29/30.. Train loss: 0.774.. Test loss: 0.269.. Test accuracy: 0.927
# Epoch 29/30.. Train loss: 0.778.. Test loss: 0.319.. Test accuracy: 0.913
# Epoch 29/30.. Train loss: 0.842.. Test loss: 0.293.. Test accuracy: 0.920
# Epoch 29/30.. Train loss: 0.707.. Test loss: 0.273.. Test accuracy: 0.924
# Epoch 29/30.. Train loss: 0.997.. Test loss: 0.340.. Test accuracy: 0.907
# Epoch 29/30.. Train loss: 0.809.. Test loss: 0.323.. Test accuracy: 0.916
# Epoch 29/30.. Train loss: 0.707.. Test loss: 0.285.. Test accuracy: 0.931
# Epoch 29/30.. Train loss: 0.868.. Test loss: 0.324.. Test accuracy: 0.910
# Epoch 29/30.. Train loss: 0.761.. Test loss: 0.337.. Test accuracy: 0.907
# Epoch 29/30.. Train loss: 1.034.. Test loss: 0.379.. Test accuracy: 0.906
# Epoch 29/30.. Train loss: 0.712.. Test loss: 0.314.. Test accuracy: 0.925
# Epoch 29/30.. Train loss: 0.806.. Test loss: 0.313.. Test accuracy: 0.921
# Epoch 29/30.. Train loss: 0.950.. Test loss: 0.301.. Test accuracy: 0.928
# Epoch 29/30.. Train loss: 1.020.. Test loss: 0.294.. Test accuracy: 0.923
# Epoch 29/30.. Train loss: 0.802.. Test loss: 0.283.. Test accuracy: 0.922
# Epoch 29/30.. Train loss: 0.761.. Test loss: 0.306.. Test accuracy: 0.916
# Epoch 29/30.. Train loss: 0.859.. Test loss: 0.271.. Test accuracy: 0.931
# Epoch 30/30.. Train loss: 1.076.. Test loss: 0.285.. Test accuracy: 0.934
# Epoch 30/30.. Train loss: 0.747.. Test loss: 0.308.. Test accuracy: 0.921
# Epoch 30/30.. Train loss: 0.831.. Test loss: 0.273.. Test accuracy: 0.925
# Epoch 30/30.. Train loss: 0.757.. Test loss: 0.303.. Test accuracy: 0.914
# Epoch 30/30.. Train loss: 0.779.. Test loss: 0.329.. Test accuracy: 0.914
# Epoch 30/30.. Train loss: 0.721.. Test loss: 0.272.. Test accuracy: 0.935
# Epoch 30/30.. Train loss: 0.727.. Test loss: 0.299.. Test accuracy: 0.914
# Epoch 30/30.. Train loss: 0.677.. Test loss: 0.317.. Test accuracy: 0.918
# Epoch 30/30.. Train loss: 0.723.. Test loss: 0.297.. Test accuracy: 0.919
# Epoch 30/30.. Train loss: 0.796.. Test loss: 0.264.. Test accuracy: 0.925
# Epoch 30/30.. Train loss: 1.116.. Test loss: 0.301.. Test accuracy: 0.921
# Epoch 30/30.. Train loss: 0.981.. Test loss: 0.285.. Test accuracy: 0.929
# Epoch 30/30.. Train loss: 0.862.. Test loss: 0.287.. Test accuracy: 0.931
# Epoch 30/30.. Train loss: 0.812.. Test loss: 0.261.. Test accuracy: 0.927
# Epoch 30/30.. Train loss: 0.858.. Test loss: 0.291.. Test accuracy: 0.916
# Epoch 30/30.. Train loss: 0.804.. Test loss: 0.267.. Test accuracy: 0.931
# Epoch 30/30.. Train loss: 0.935.. Test loss: 0.302.. Test accuracy: 0.934
# Epoch 30/30.. Train loss: 0.700.. Test loss: 0.306.. Test accuracy: 0.916
# Epoch 30/30.. Train loss: 0.849.. Test loss: 0.322.. Test accuracy: 0.911
# Epoch 30/30.. Train loss: 0.706.. Test loss: 0.278.. Test accuracy: 0.933
# Epoch 30/30.. Train loss: 0.822.. Test loss: 0.403.. Test accuracy: 0.880

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = image_datasets[0].class_to_idx

checkpoint = {'input_size': 1024,
              'output_size': 102,
              'class_to_idx': model.class_to_idx,
              'state_dict': model.state_dict()
}

torch.save(checkpoint, 'drive/checkpoint4.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    
    #model = classifier(checkpoint['input_size'],
     #                  checkpoint['output_size'])
    model.load_state_dict(checkpoint['state_dict'])
        
    return model
  
model = load_checkpoint('drive/checkpoint4.pth')
print(model)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=512, out_features=102, bias=True)
#     (4): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    im = Image.open(image)
    im = im.resize((256,256))
    value = 0.5*(256-224)
    im = im.crop((value,value,256-value,256-value))
    im = np.array(im)/255

    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    im = (im - mean) / std

    return im.transpose(2,0,1)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    cuda = torch.cuda.is_available()
    if cuda:
        # Move model parameters to the GPU
        model.cuda()
        print("Number of GPUs:", torch.cuda.device_count())
        print("Device name:", torch.cuda.get_device_name(torch.cuda.device_count()-1))
    else:
        model.cpu()
        print("We go for CPU")
    
    # turn off dropout
    model.eval()

    # The image
    image = process_image(image_path)
    
    # tranfer to tensor
    image = torch.from_numpy(np.array([image])).float()
    
    # The image becomes the input
    image = Variable(image)
    if cuda:
        image = image.cuda()
        
    output = model.forward(image)
    
    probabilities = torch.exp(output).data
    
    # getting the topk (=5) probabilites and indexes
    # 0 -> probabilities
    # 1 -> index
    prob = torch.topk(probabilities, topk)[0].tolist()[0] # probabilities
    index = torch.topk(probabilities, topk)[1].tolist()[0] # index
    
    ind = []
    for i in range(len(model.class_to_idx.items())):
        ind.append(list(model.class_to_idx.items())[i][0])

    # transfer index to label
    label = []
    for i in range(5):
        label.append(ind[index[i]])

    return prob, label
    # TODO: Implement the code to predict the class from an image file

# %%
img_path = 'drive/flower_data/valid/1/image_06739.jpg'

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the validation accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
prob, classes = predict(img_path, model)
max_index = np.argmax(prob)
max_probability = prob[max_index]
label = classes[max_index]

fig = plt.figure(figsize=(6,6))
ax1 = plt.subplot2grid((15,9), (0,0), colspan=9, rowspan=9)
ax2 = plt.subplot2grid((15,9), (9,2), colspan=5, rowspan=5)

image = Image.open(img_path)
ax1.axis('off')
ax1.set_title(cat_to_name[label])
ax1.imshow(image)

labels = []
for cl in classes:
    labels.append(cat_to_name[cl])
    
y_pos = np.arange(5)
ax2.set_yticks(y_pos)
ax2.set_yticklabels(labels)
ax2.set_xlabel('Probability')
ax2.invert_yaxis()
ax2.barh(y_pos, prob, xerr=0, align='center', color='blue')

plt.show()
# Out:
# Number of GPUs: 1
# Device name: Tesla K80
